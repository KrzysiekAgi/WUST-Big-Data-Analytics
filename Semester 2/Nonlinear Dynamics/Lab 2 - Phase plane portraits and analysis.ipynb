# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
init_printing(use_unicode=True)

# %% [markdown]
# # 1.1 Four stationary points

# %%
from sympy import Symbol
x,y = symbols('x y')
P = 16*x**2 + 9*y**2 - 25
Q = 16*x**2 - 16*y**2
solve({P,Q},{x,y})
# Out:
# [{x: -1, y: -1}, {x: -1, y: 1}, {x: 1, y: -1}, {x: 1, y: 1}]

# %%
a = diff(P, x)
b = diff(P, y)
c = diff(Q, x)
d = diff(Q, y)
print(a, b, c, d)
# Out:
# 32*x 18*y 32*x -32*y

# %%
x1 = -1
y1 = 1
a1 = a.subs(x,x1)
b1 = b.subs(y,y1)
c1 = c.subs(x,x1)
d1 = d.subs(y,y1)
q = a1*d1-b1*c1
p = -a1-d1
r = p**2-4*q
print(p,q,r)
# Out:
# 64 1600 -2304

# %%
init_printing(use_unicode=True)
x = Function('x')
y = Function('y')
t = symbols('t')
diffeq1 = 16*x(t)**2 + 9*y(t)**2 - 25
diffeq2 = 16*x(t)**2 - 16*y(t)**2
diffeq2
# Out:
#     2          2
# 16⋅x (t) - 16⋅y (t)

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import ma

X, Y = np.meshgrid(np.arange(-2, 2, .1), np.arange(-2, 2, .1))
U = 16*X**2 + 9*Y**2 - 25
V = 16*X**2 - 16*Y**2

plt.figure()
plt.title('Tangent Field')
Q = plt.quiver(X, Y, U, V, units='width')
fixed = plt.scatter([-1,-1,1,1],[-1,1,-1,1])

plt.show()

# %% [markdown]
# # 1.2 Famous phaseportraits

# %% [markdown]
# ### 1.2.1 Lorenz Butterfly

# %%
sigma, b, r = symbols('sigma b r')
x = Function('x')
y = Function('y')
z = Function('z')
difeq1 = sigma*(y(t)-x(t))
difeq2 = -x(t)*z(t) + r*x(t) - y(t)
difeq3 = x(t)*y(t) - b*z(t)


x0 = 0.1
y0 = 0.1
z0 = 0.1
r_ = 28
b_ = 8/3
sigma_ = 10

difeq1_ = difeq1.subs([sigma, x, y],[sigma_, x0, y0])
difeq2_ = difeq2.subs([x, y, z, r],[x0, y0, z0, r_])
difeq3_ = difeq3.subs([x, y, z, b],[x0, y0, z0, b_])

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(difeq1_, difeq2_, difeq3_, label='parametric curve')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cb0c7efbf47f> in <module>
#      11 x = r * np.sin(theta)
#      12 y = r * np.cos(theta)
# ---> 13 ax.plot(difeq1_, difeq2_, difeq3_, label='parametric curve')
#      14 ax.legend()
#      15
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1536
#    1537         # Match length
# -> 1538         zs = np.broadcast_to(zs, len(xs))
#    1539
#    1540         lines = super().plot(xs, ys, *args, **kwargs)
#
# TypeError: object of type 'Mul' has no len()

# %% [markdown]
# ### 1.2.2 Rössler’s strange attractor

# %%
# TODO

# %% [markdown]
# ### 1.2.3 Oregonator: limit cycle

# %%
# TODO
