# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt

# %%
x = symbols('x')
eq1 = x**2 + 4*x - 5
solve(eq1, x)
# Out:
# [-5, 1]

# %%
x, y = symbols('x y')
polyn = x**3 + 7*x*y + y**2
a = Poly(polyn, x, y)
a.coeffs()
# Out:
# [1, 7, 1]

# %%
x, y, a = symbols('x y a')
expr = 2*x**3 + x**4 + a*x**3
collect(expr, [x, y])
# Out:
# x**4 + x**3*(a + 2)

# %%
# %matplotlib inline

# %%
x = np.linspace(-1, 1, 50)
y = x**2
y1 = 1-x**2

plt.plot(x, y)
plt.plot(x, y1)
plt.show()

# %%
x = np.linspace(0, 6.28, 50)
y_sin = np.sin(x)
plt.plot(x, y_sin)

# %%
x, y = symbols('x y')
eq = x**2*y
diff(eq, x) # first derivative
diff(diff(eq, x), x) # second derivative
diff(eq, x, x) # same as above
# Out:
# 2*y

# %%
x, t = symbols('x t')
L = [1,x**2, t]
L[1]
# Out:
# x**2

# %%
n = symbols('n')
sequence(n**2, (n, 0, 5))
# Out:
# SeqFormula(n**2, (n, 0, 5))

# %%
x = symbols('x')
#f =lambda x: x*sin(x)
f = x*sin(x)
nsolve(f,2.0)
# Out:
# -1.24391434130207e-6

# %%
x = np.linspace(0, 10, 500)
y = x*np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x,y = symbols('x y')
f3 = x*sin(y)
N(f3, 50)
# Out:
# x*sin(y)

# %%
# to be run in console as: python -i script_name.py
from sympy import var, Plot
var('x y z')
Plot(x*y**3-y*x**3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-56-c2c4114966fd> in <module>
#       1 # to be run in console as: python -i script_name.py
# ----> 2 from sympy import var, Plot
#       3 var('x y z')
#       4 Plot(x*y**3-y*x**3)
#
# ImportError: cannot import name 'Plot' from 'sympy' (C:\Users\kagiencz\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\__init__.py)

# %%
init_printing(use_unicode=True)
x = Function('x')
diffeq1 = diff(x(t), t) + t*x(t) - sin(t)
diffeq1
# Out:
#                   d
# t⋅x(t) - sin(t) + ──(x(t))
#                   dt

# %%
x, y, z = symbols('x y z')
expr = exp(x*y*z)
deriv = Derivative(expr, x, y, y, z, 4)
deriv.doit()
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %%
x = Function('x')
diffeq1 = diff(x(t), t, t) + t*x(t) - sin(t) #second order diff eq
diffeq1
# Out:
#                     2
#                    d
# t⋅x(t) - sin(t) + ───(x(t))
#                     2
#                   dt
