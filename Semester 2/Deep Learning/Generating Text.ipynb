# %%
import numpy as np
import keras
# Out:
# Using TensorFlow backend.

# %%
def recalculate_distribution(original_distrib, temperature=0.5):
    distrib = np.exp(np.log(original_distrib)/temperature)
    return distrib/np.sum(distrib)

# %%
path = keras.utils.get_file('nietzsche.txt',origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600901

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text)-maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])
    
print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters: ', len(chars))
char_indices = dict((char,chars.index(char)) for char in chars)


# One-hot encode
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i,t,char_indices[char]] = 1
    y[i,char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters:  59

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128,input_shape=(maxlen,len(chars))))
model.add(layers.Dense(len(chars),activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temp=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds)/temp
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1,10):
    print('epoch ', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text)-maxlen-1)
    generated_text = text[start_index: start_index+maxlen]
    print('\n--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n------ temperature:', temperature)
        sys.stdout.write(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0,t,char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch  1
# Epoch 1/1
# 200281/200281 [==============================] - 392s 2ms/step - loss: 1.5146
#
# --- Generating with seed: " of woman is slowly evolving? oh europe! europe! we know
# the"
#
# ------ temperature: 0.2
#  of woman is slowly evolving? oh europe! europe! we know
# the history of the spirit of the same not of the presence of the presence of the sense and the sense of the present of the presence of the sense of the presence of the present to the presence of the religious and the same time of the same and will and deceives to the same by the present of the same time of the same time and sense of the presence of the same time of the presence of the same part of th
# ------ temperature: 0.5
# ence of the same time of the presence of the same part of the distinctive has
# invilling in the same histiness, it is antither and stand of the mankind to the nature and christian right and pirts of his religion of the prigise in the sense presence of the distinction of the briepened to the how and sympathy is presence of the faitions of the same call as a stranges of the presence of presence that all the disposed his will to all the consequently and soul a
# ------ temperature: 1.0
# all the disposed his will to all the consequently and soul affarded make us. nothingly as it--as can notlerowged lark nature and the a
# being mind frugmiral spirit at they selfthing
# musfperries, and
# linerinow-, brandard to neivivissstemnth the
# yet as other, world "belief "which as the clase in conscience---and in got had complacity and last through many--backing of has the didenslationsomingly to be from at its will not antious rank regarded and pare of itu
# ------ temperature: 1.2
# e from at its will not antious rank regarded and pare of itur's, whellys as philosophart trangvecto; in the holighted villentions, wiskow than of all ninabod beeve a on belorosign .teil evel-wise to his will be goilat abwarc uppases crupief,
# perhaps hencesd thing oboroundurspchoend will gods, but on fastiminas delurately
# power, to go
# pradicihy for nothen distills beloived cimedy of ausetionall"
# awand. soat in conbluvion of thinj pwinr,
# to absuidaging heantepoch  2
# Epoch 1/1
# 200281/200281 [==============================] - 363s 2ms/step - loss: 1.4742
#
# --- Generating with seed: "lso were only obeying. this condition of things
# actually exi"
#
# ------ temperature: 0.2
# lso were only obeying. this condition of things
# actually existence of the superiority of the superficial the sense the same the sense, the stronger the same the same the same the self-mankind the say of the condition and the same present promise of the problem of the superiority of the sense of the condition of the problem of the same the contrious of the sense, the sense, and the sense, the self-contrious of the problem of the problem of the problem of th
# ------ temperature: 0.5
# contrious of the problem of the problem of the problem of the best of the delicate of the except of the firstly indepoltion of the trouble of the problem of the notion of the same insist the presentie existing the world
# prosent with all him in which it
# intenttence of the condition the sance of the present deem in the self-conduct the truth intellect of the relication of the streashing and the all the truth the time as so its problem and possibility of the
# ------ temperature: 1.0
# the truth the time as so its problem and possibility of the bture of the anvilifie.b
# amil and for: a
# mosp pisside. not period upine seausiffects even mysth who fether mere
# most "desprysion, self-excesses, hely fet disconting belieft--that realm of mankin god, should them, couloutance--as old proophounic of in we degree inophiesting to heart, at a peters itself that as ;tert"ed bads be us one spiritsbids that why rendather
# frenly over
# alsomer the kemoon and
# ------ temperature: 1.2
# tsbids that why rendather
# frenly over
# alsomer the kemoon and
# interrigirert. he is no so, longer
# except and sharposus), the jest now when aspocien so manhirably eyes
# god, and who  sundaul.bze of ones less a same
# that rully is mavesacy by acularal  inha"gy high i "those tralfy, afuligh; and no outhueal and insjubedafity,
# but sneftor.
# thes throughe themselves itself use constrdve unfactive il cauling and not they remainsely s,e, but or faith womanerly one thiepoch  3
# Epoch 1/1
# 200281/200281 [==============================] - 372s 2ms/step - loss: 1.4464
#
# --- Generating with seed: "st "froglike," mandeikagati
# [footnote: like the frog: stacca"
#
# ------ temperature: 0.2
# st "froglike," mandeikagati
# [footnote: like the frog: staccal and soul of the same to the still the spirit of the spirit of the spirit of the promise and sense of the distinction of the spirit of the distrust and to be the spirit of the same to the sense of the spirit of the free spirit of the spirit of the spirit of the spirit of the same and in the spirit of the same time that is the same to be a stronger to the spirit of the distrust to the spirit of th
# ------ temperature: 0.5
# a stronger to the spirit of the distrust to the spirit of the free forms of the opinion of the order to all the man in the worth of the most into the truth of inspire enough and self her new as a extent to his strength of the here alive of moral expecially to deal similate takes, and and obediently for the reason of the promise in his oper to the forms arious intellication of the awaking of the spirit and a fact that all the spirit of meaniness of the dist
# ------ temperature: 1.0
# irit and a fact that all the spirit of meaniness of the distrust? we discah to beleaust, of hurposich intelligebedten
# i finally the delight as it" of the have the rebure
# his longer in his evolutional his
# dulied and existence, all know ad good. always of massely medicong of beonded thas tevituos to tecdby on a blooiabs
# hand put certain may be fos the eways become the valuation and science funl this proto and purture, upeer enough must interparses,
# howevy wi
# ------ temperature: 1.2
#  proto and purture, upeer enough must interparses,
# howevy without thus iautar oftel-evened, pertain offuls and
# buins to
# gymitys for of the costy thereby stands to evards trans"s e?ury.=--wh ry recouls
# to the spread witen,
# veremning. it delife
# battbute knowi-natural helped que of ane philosophy german? "their twone reastes: as a
# franafing,
# in; proger. there is, into og;
# hardly enough of furnt solituting is thealing rights upther? who hou
# greesrfies of germaepoch  4
# Epoch 1/1
# 200281/200281 [==============================] - 434s 2ms/step - loss: 1.4254
#
# --- Generating with seed: "alist would like to exercise power and
# creative arbitrarines"
#
# ------ temperature: 0.2
# alist would like to exercise power and
# creative arbitrariness, that a distrust and democratic and the still and the still the soul and the spirit of the sense that a common that the way that the spirit of the will the soul and the sense of the spirit and still the common with the spirit and act of the soul and the will and and the sense of the soul and act of the sense of the sense of a distrust and in the still the still and something that is a soul and n
# ------ temperature: 0.5
# nd in the still the still and something that is a soul and not could not a religion
# a belief that the
# any virtue that how do still something to the abservation and worker of the people of the still the common
# higher of a most pain a parts, as a generally the individual and in the and most soul that it seems to be the care of the desire of the personal and confedious and with fact that it is here a look in its action and self-destrust.
#
# simple and spirit in
# ------ temperature: 1.0
#  look in its action and self-destrust.
#
# simple and spirit in -barmin him;er erpo, and trafeded
# for the formulived to
# science, superally appearably with the indofunish, first of
# an indealned cyus," imposcionality of hit
# any interricial,
# wholoug that perhaps man to gooth, seet but not  many falseh: territy and perceas, nost himself, which ordanialy
# aways--those
# at his propee bark. but as prese-their
# matker.--that the hiden should be at being for, as that our
# ------ temperature: 1.2
#
# matker.--that the hiden should be at being for, as that our commanders of fastious clahm thind, this ashererlys with ogariby,
# the rpising sertinity, however. -it
# is
# realintaled" any us
# lainar,
# tkins or different  is hundablosms to disclial at animal aiduded
# contemplous,thequienal spirincted as life of
# their
# understast.
# his welted harre ages, a, entlupents its sits
# of science, it most beitming a sh? the noblight of the whatgowing it when hirmyly under it iepoch  5
# Epoch 1/1
# 200281/200281 [==============================] - 295s 1ms/step - loss: 1.4084
#
# --- Generating with seed: "h to possess a talent: one must also have your
# permission to"
#
# ------ temperature: 0.2
# h to possess a talent: one must also have your
# permission to the experience that the other that in the still and and the sense of the spirit and man in the same man in the most power of the spirit in the spirit in the spirit and the sense and the sense of the spirit in the subject that the sense and the more of the consequently the good in the sense of the spirit and the soul and the sense of the subjection of the spirit in the sense of the spirit in the c
# ------ temperature: 0.5
# subjection of the spirit in the sense of the spirit in the consequenth as a more benefomes and one must be hopenrs not to all distrust and now that a profound and that the other and time of the spirit and could an in the subtle and as in the consequents. if what is a man in it is as in the discreding and part of man is not for the same german soul of continually and gradifice and every finest spinity of the provess that art, and in the soble of all the "th
# ------ temperature: 1.0
# ity of the provess that art, and in the soble of all the "thingrous sense rimitude and very inconstinction for what averart thoughts and great such at the wishourage of the perhaps "geanning the coonness of good formulan as is beauty the opinian command the spriny well good of the usiunable opine? it will tender hereved too modernen--it only becomen is oneted with finally paticular--thinking hharded time of highted as than one to and wefforitable. there wi
# ------ temperature: 1.2
# ed time of highted as than one to and wefforitable. there wills which talk besond
# it
# excitually
# cotividity of the peeraul. as cours timed called covery and greeks, vieve. inderence, to
# incermed, sinly
#
# and
# creeks your now-deallys let yepted romide to heove of leasen: euromes hy rarp that is sieply temlines of ?uptisplace. in the towarys, that in himself i voluntived -rejuiente modes all
# errudoman there
# upitedques, and h abiled by anyagh,
# for nobje,
# in anyepoch  6
# Epoch 1/1
# 200281/200281 [==============================] - 288s 1ms/step - loss: 1.3948
#
# --- Generating with seed: "            12.
#
#      pinings of youth that might not unders"
#
# ------ temperature: 0.2
#             12.
#
#      pinings of youth that might not understand the suffering of the truth and such a sure to the suffering of the sight of the superiority of the survetical soul and strength of the same present the suffering and such as the sense of the sense of the contrangerous spirits and the sense of the commands and conscience the states of the states of the contrangerous strength of the superiority of the same time and states of the sense of the st
# ------ temperature: 0.5
# periority of the same time and states of the sense of the strength of the soul the soul and apprehorsing which all the will and same gast reverent and distrusting europe of the
# greatest and callinate them and and as the
# unifulance the terrible the actions and only the conscience of the commandes, and still the sense of the spirit
# is a soul to the german soul--it is not pardon this anguet how much to the states is we
# the same destrust
# as says, and are not g
# ------ temperature: 1.0
# to the states is we
# the same destrust
# as says, and are not good
# nature, as reneremed i a ression, more fholtist, which error "sdechortoge ot authories-loftrises of name mysich as thoughd
# time fercours. a situation of the corrocious tandons
# is evo satisfvely and
# father
# almontify. the awarge falsely firity might fals
# warted
# said of notions the odication
# present seed depthing the german surcefvett, he is longer now, the surhifge that this so paid to there of
# ------ temperature: 1.2
# e is longer now, the surhifge that this so paid to there of near, mort,
# or
# nature, longer! faven pervagld ages
# to taking  cynishhmnoys
# proved parh has been am"igions of him what was e tim the frodious." the srinl
# feith to this oy? peruated. whence
# his general takenk ferlisming that hardon wises, sevengeony see.--if at od this unpaules--a down tystic very epicugusations alm who looks. rrostious
# and
# must
# bh
# prevates almow childs eye iven thus father
# had boorepoch  7
# Epoch 1/1
# 200281/200281 [==============================] - 309s 2ms/step - loss: 1.3864
#
# --- Generating with seed: "he
# instinct for people like himself, and for that which they"
#
# ------ temperature: 0.2
# he
# instinct for people like himself, and for that which they can be something the sense of the state of the problem of the sense of the problem of the same precisely the sense of the present in the spiritual sense of the sense of the sense of the state of the state of the problem of the still of the sense of the soul of the sense of the sense and state of the sense of the subjection of the still the subjection of the other suffering the sense of the sense
# ------ temperature: 0.5
# he subjection of the other suffering the sense of the sense of present interpreting the self above a propours to the restural the present with the persision of the concealed the same polse the conscious fations of the profounders of the extent of the free spirit of the spiritual and schope and the faith, and in one sensition and great the same times of the spirits in which the german time
# creating the german for instance, it is in the same and every one fr
# ------ temperature: 1.0
#  the german for instance, it is in the same and every one from the will he "calper-hims, but but is booked pation, and that merhomerance already
# bap, the other stating to the are aristoted into their intelluither. it wantes, can yes will, has order that being renceed"
# extraries of physioled subjection is seht, much
# rejutijostly monder in
# all the religionasity, or in the "freesoon almosi the spell consuction, that which the
# perceins of virtue upsee, "manifi
# ------ temperature: 1.2
# consuction, that which the
# perceins of virtue upsee, "manificiatian, circeour, be it maniy
# not likeed re sympathy main yor and indurge,
# one potses i wealthtigi. that utribsity, is become farthjoy
# that if is,
# or cliives it could be free surepnusing goeth-plantinged an ammints and duting pruden aimhs
# is it anti
# eristory; the kind, as assilfer what.
#
#
# cot we loakes withtrechedges"
# and "holdlecous futured from him. the good kinds--are seets anewy is mistruth
# jepoch  8
# Epoch 1/1
# 200281/200281 [==============================] - 287s 1ms/step - loss: 1.3761
#
# --- Generating with seed: "ghts, whereas it is
# unconsciously assumed that principal and"
#
# ------ temperature: 0.2
# ghts, whereas it is
# unconsciously assumed that principal and and who all the antice and the strongest standard and considerable the sense of the problem of the same the sense of the presence of the states of the states of the states of the problem of the spirit of the sense of the spirit of the spirit of the stronger the stronger and all the same time and the same time and and the states of the problem of the sense of the problem of the sense of the states
# ------ temperature: 0.5
# oblem of the sense of the problem of the sense of the states and the strongest intelligely the philosophe, and would be strictly, the states that all the best the states to religious religious when his same pasters, in the commonsself to the bad the solitual to a distinction of the enjoyment of the bastion and should have been any souls, the spirit of the most preproxtory and the process of the profound and commands, to be like the same time souls--and in
# ------ temperature: 1.0
# ofound and commands, to be like the same time souls--and in theise tempalen refutule namelations, for
# the roys the ranglience which, to
# almotist  and conduct fanted.
#
#
# 41
#
# =norwary what the sables, as daymentiness to booked, immernosh"), and
# oginit, was o. to what years are a refiner effect masterward rebliling possible belief honous sougal injureablement of which actually colnetering, less secret
# eity, germany,
# unegived, play anything that it but nor cong
# ------ temperature: 1.2
#
# eity, germany,
# unegived, play anything that it but nor congenulow for ethicsh, are at them unnuies or justice itself,
# gurotives.--the latterez; at thoseped weaitation fait it. whichevlessess foo orp and onearis fors and wreting and are
# acture opinion there all  and
# a like that "the more gomey, it
# unboum. advantical abstility, see
# have longs of labouds more salsiants."
#
#
# 1iserook rewarding grateful"menthe erbrated, her-historical wills.
#  evereined  : "but epoch  9
# Epoch 1/1
# 200281/200281 [==============================] - 343s 2ms/step - loss: 1.3686
#
# --- Generating with seed: " more
# bruised, but full of hopes which as yet lack names, fu"
#
# ------ temperature: 0.2
#  more
# bruised, but full of hopes which as yet lack names, funderation of the strongess of the entire for the fact that it is a success the strong and society of the former the problem of the strongess of the sense of the feelings, and the sense of the sense of the former and delivist and society of the condition of the problem of the sense of the sense of the sense of the strongess and the sense of the former the world and the sense of the sense of the str
# ------ temperature: 0.5
# f the former the world and the sense of the sense of the struggle who has a more aget and are not the coarse in the feeling of the work and embing eme his the cases of the sympathy for the same time of europe, and one must strong as a very form in more
# and for the world and the world can be a minds and an embillen to expression, or to the expressions, the conscience work and
# the other experition of the conditions of the world and strong as a more of indivi
# ------ temperature: 1.0
# f the conditions of the world and strong as a more of individuating youthies free world
# of
# centuri gratifusd in, voluntary could increasation and than present
# sensible, but when is hargings" hacking--their
# degree of the being deceptions. perhaps the ruti" to find himself this
# for s"may of their intellectual one" for branties, not relicant and the be destrained betrioitonal explousous is abstration of arr" the problem is
# charactert promis. we beway
# as himse
# ------ temperature: 1.2
#  of arr" the problem is
# charactert promis. we beway
# as himself--and
# whole.
#
# stass".ly danger.
#
#       ind itwayd for famile
# the regard, or uninative (for being to
# spends of the rearing to this dejuin agort from tkin even in
# accoriatical men for the hear--both it who must has prdexe of long, but
# brother pich symbetes:
# opinion--ye names dictuderay
# wogen. we hentiments wise trilly reor nowadays to but
# as sons af betfore, vivise attled for-in all musbopws, in m
